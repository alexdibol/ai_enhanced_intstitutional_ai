# %% [markdown]
# # NB09 - Relationship Graph
#
# **Objective:** Construct explicit governed relationships among CKOs.
#
# Part of **The ExoBrain Project: Engineering Human Cognitive Operating Systems in the Age of Artificial Intelligence**.

# %%
from pathlib import Path
import sys, json
# Locate package root whether running locally or in Colab after upload/unzip
HERE=Path.cwd().resolve()
ROOT=next((p for p in [HERE,*HERE.parents] if (p/'04_Source_Code/exobrain.py').exists()), None)
if ROOT is None:
    raise FileNotFoundError('Open the notebook from inside the extracted reference package.')
sys.path.insert(0,str(ROOT/'04_Source_Code'))
import exobrain as ex
CORPUS=ROOT/'03_Synthetic_Corpus'
OUT=ROOT/'05_Outputs'
OUT.mkdir(exist_ok=True)
print('Project root:',ROOT)

# %% [markdown]
# ## Load CKOs

# %%
ckos=ex.read_json(OUT/'NB08_ckos.json') if (OUT/'NB08_ckos.json').exists() else ex.build_ckos(CORPUS,ex.read_json(OUT/'NB06_corpus_manifest.json'))
len(ckos)

# %% [markdown]
# ## Build relationship graph

# %%
relationships=ex.build_relationships(ckos)
ex.write_json(OUT/'NB09_relationships.json',relationships)
print('Relationships:',len(relationships))
relationships[:3]

# %% [markdown]
# ## Validate endpoints

# %%
ids={c['cko_id'] for c in ckos}
valid=all(r['source'] in ids and r['target'] in ids for r in relationships)
assert valid
{'all_endpoints_valid':valid}

# %% [markdown]
# ## Completion
# The notebook has generated its governed outputs in `05_Outputs/`.
