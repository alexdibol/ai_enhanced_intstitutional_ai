# %% [markdown]
# # NB10 - CKO Registry
#
# **Objective:** Create a persistent registry containing CKOs and their relationships.
#
# Part of **The ExoBrain Project: Engineering Human Cognitive Operating Systems in the Age of Artificial Intelligence**.

# %%
from pathlib import Path
import sys, json
# Locate package root whether running locally or in Colab after upload/unzip
HERE=Path.cwd().resolve()
ROOT=next((p for p in [HERE,*HERE.parents] if (p/'04_Source_Code/exobrain.py').exists()), None)
if ROOT is None:
    raise FileNotFoundError('Open the notebook from inside the extracted reference package.')
sys.path.insert(0,str(ROOT/'04_Source_Code'))
import exobrain as ex
CORPUS=ROOT/'03_Synthetic_Corpus'
OUT=ROOT/'05_Outputs'
OUT.mkdir(exist_ok=True)
print('Project root:',ROOT)

# %% [markdown]
# ## Load components

# %%
ckos=ex.read_json(OUT/'NB08_ckos.json')
relationships=ex.read_json(OUT/'NB09_relationships.json') if (OUT/'NB09_relationships.json').exists() else ex.build_relationships(ckos)

# %% [markdown]
# ## Build registry

# %%
registry=ex.registry(ckos,relationships)
ex.write_json(OUT/'NB10_cko_registry.json',registry)
registry['registry_id'],registry['cko_count'],registry['relationship_count']

# %% [markdown]
# ## Confirm deterministic fingerprint

# %%
again=ex.registry(ckos,relationships)
assert registry['fingerprint']==again['fingerprint']
{'stable_fingerprint':True,'fingerprint':registry['fingerprint']}

# %% [markdown]
# ## Completion
# The notebook has generated its governed outputs in `05_Outputs/`.
